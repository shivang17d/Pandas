# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('employees.csv')

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.pivot_table(index='Team',columns='First Name',values='Salary',aggfunc='mean')
# Out:
# First Name              Aaron      Adam      Alan    Albert          Alice  \
# Team
# Business Development      NaN       NaN       NaN   91467.0            NaN
# Client Services       57622.5       NaN       NaN       NaN            NaN
# Distribution              NaN   95327.0       NaN       NaN            NaN
# Engineering               NaN       NaN  111786.0   77322.5  131952.000000
# Finance                   NaN       NaN   40341.0  102626.0  106994.666667
# Human Resources           NaN   58228.5       NaN       NaN   47638.000000
# Legal                     NaN       NaN       NaN       NaN            NaN
# Marketing             60178.5       NaN       NaN       NaN            NaN
# Product                   NaN  110194.0   41453.0       NaN   63571.000000
# Sales                     NaN       NaN       NaN  129949.0   92799.000000
#
# First Name              Amanda       Amy    Andrea    Andrew   Angela  ...  \
# ...

# %%
df.pivot_table(index=['Team','Gender'],columns='First Name',values='Salary',aggfunc='mean')
# Out:
# First Name                     Aaron      Adam      Alan    Albert     Alice  \
# Team                 Gender
# Business Development Female      NaN       NaN       NaN       NaN       NaN
#                      Male        NaN       NaN       NaN   91467.0       NaN
# Client Services      Female      NaN       NaN       NaN       NaN       NaN
#                      Male    52119.0       NaN       NaN       NaN       NaN
# Distribution         Female      NaN       NaN       NaN       NaN       NaN
#                      Male        NaN   95327.0       NaN       NaN       NaN
# Engineering          Female      NaN       NaN       NaN       NaN  131952.0
#                      Male        NaN       NaN  111786.0   77322.5       NaN
# Finance              Female      NaN       NaN       NaN       NaN   86322.5
#                      Male        NaN       NaN       NaN  102626.0       NaN
# Human Resources      Female      NaN       NaN       NaN       NaN   47638.0
# ...

# %%
df.pivot_table(index=['Team','Gender'],columns=['First Name','Start Date'],values='Salary',aggfunc='mean')
# Out:
# First Name                      Aaron                          Adam  \
# Start Date                  1/29/1994 2/17/2012 7/22/1990 10/8/2010
# Team                 Gender
# Business Development Female       NaN       NaN       NaN       NaN
#                      Male         NaN       NaN       NaN       NaN
# Client Services      Female       NaN       NaN       NaN       NaN
#                      Male         NaN       NaN   52119.0       NaN
# Distribution         Female       NaN       NaN       NaN       NaN
#                      Male         NaN       NaN       NaN       NaN
# Engineering          Female       NaN       NaN       NaN       NaN
#                      Male         NaN       NaN       NaN       NaN
# Finance              Female       NaN       NaN       NaN       NaN
#                      Male         NaN       NaN       NaN       NaN
# Human Resources      Female       NaN       NaN       NaN       NaN
# ...
